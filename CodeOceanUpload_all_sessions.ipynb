# %%
# imports
import os
import numpy as np
import datetime
import pandas as pd
#import BCI_analysis
from pathlib import Path
import subprocess

# %%
# generate a csv file and collect data in folders if necessary.
metadata_dir = '/home/jupyter/bucket/Metadata/' 
dlc_base_dir = os.path.abspath("/home/jupyter/bucket/Data/Behavior_videos/DLC_output/Bergamo-2P-Photostim/")
bpod_path = os.path.abspath("/home/jupyter/bucket/Data/Behavior/BCI_exported/Bergamo-2P-Photostim/")
suite2p_path = os.path.abspath("/home/jupyter/bucket/Data/Calcium_imaging/suite2p/Bergamo-2P-Photostim/")
raw_imaging_path = os.path.abspath("/home/jupyter/bucket/Data/Calcium_imaging/raw/Bergamo-2P-Photostim/")

sessionwise_data_path = os.path.abspath("/home/jupyter/bucket/Data/Calcium_imaging/sessionwise_tba/")

face_rhythm_base_dir = '/home/jupyter/bucket/Data/Behavior_videos/FaceRhythm/'
motion_energy_base_dir = os.path.abspath("/home/jupyter/bucket/Data/Behavior_videos/MotionEnergy/Bergamo-2P-Photostim/")
raw_video_path = os.path.abspath("/home/jupyter/bucket/Data/Behavior_videos/raw/Bergamo-2P-Photostim/")

CO_save_path = "/home/jupyter/bucket/CodeOcean_transfer/"

sessions_with_errors = [] # sessions that are skipped collected in this list
no_cn_sessions = []
invalid_neurons = [] # with inf
blacklist = []
mat_files = []
session_dates = {}
kept_files = []
files_thrown_away = []
only_csv_metadata = False
for mouse_id in os.listdir(raw_imaging_path):
    
    if 'BCI' not in mouse_id:
       # print('{} is not a proper subject name, skipping'.format(mouse_id))
        continue
    for session in os.listdir(os.path.join(raw_imaging_path,mouse_id)):
        try:
            datetime.datetime.strptime(session,'%m%d%y')
        except:
            #print('{} is not a proper session folder, skipping'.format(session))
            continue
        if mouse_id not in session_dates.keys():
            session_dates[mouse_id] = {}
        session_dates[mouse_id][datetime.datetime.strptime(session,'%m%d%y')]  = [session]
        
        
        
upload_dict = {'platform':[],
                'acq_datetime':[],
                'subject_id':[],
                's3_bucket':[],
                'modality0':[],
                'modality0.source':[],
                'modality1':[],
                'modality1.source':[],
                'modality2':[],
                'modality2.source':[]}
#asdsa
platform = 'single-plane-ophys'
s3_bucket = 'aind-ophys-data'
df_metadata=pd.read_csv(os.path.join(metadata_dir,'Surgeries-BCI.csv'))
for mouse_id in session_dates.keys():
    mouseid = mouse_id
    while mouseid.find('_')>-1:
        mouseid = mouseid[:mouseid.find('_')]+mouseid[mouseid.find('_')+1:]
    for session_date in np.sort(list(session_dates[mouse_id].keys())):
        [session] = session_dates[mouse_id][session_date]
        # load metadata to find subject_id
        try:
            
            try:
                subject_id = int(df_metadata.loc[df_metadata['ID']==mouse_id,'animal#'].values[0])
            except:
                subject_id = int(df_metadata.loc[df_metadata['ID']==mouseid,'animal#'].values[0])
                
        except:
            subject_id = None
            print('missing subject id for {} ..  skipping'.format(mouse_id))
            break
        
        # load exported bpod data to find acq datetime
        behavior_fname = os.path.join(bpod_path,mouse_id, f"{session}-bpod_zaber.npy")
        try:
            bpod_dict = np.load(behavior_fname,allow_pickle = True).tolist()
        except:
            print('no behavior found, skipping')
            continue
        
        idx = -1
        tiffheader = np.nan
        while np.abs(idx)<len(bpod_dict['scanimage_tiff_headers']):
            try:
                tiffheader = bpod_dict['scanimage_tiff_headers'][idx].tolist()[0]
                break
            except:
                idx-=1
        last_trial_time = tiffheader['movie_start_time'] + datetime.timedelta(seconds = float(tiffheader['description_first_frame']['frameTimestamps_sec']))
        
        gotit = False
        i_ = 0
        while not gotit:
            i_-=1
            try:
                last_residual_tiff_time = bpod_dict['residual_tiff_files']['scanimage_tiff_headers'][i_]['movie_start_time']+ datetime.timedelta(seconds = float(bpod_dict['residual_tiff_files']['scanimage_tiff_headers'][i_]['description_first_frame']['frameTimestamps_sec']))
                gotit = True
            except:
                pass
        session_end_time = np.max([last_trial_time,last_residual_tiff_time])
        
        acq_datetime = datetime.datetime.strftime(session_end_time, '%Y-%m-%d %H-%M-%S')
        
        # locate raw imaging data (no copy required, only folder name)
        modality0 = 'ophys'
        modality0_source = os.path.join(raw_imaging_path,mouse_id,session)
        
        
        #copy behavior stuff in a folder
        modality1 = 'trained_behavior'
        modality1_source = Path(os.path.join(CO_save_path,'{}-{}'.format(mouse_id,session),'behavior'))
        modality1_source.mkdir(parents=True, exist_ok=True)
        copy_command = 'gsutil cp {} {} '.format(behavior_fname,str(modality1_source)+'/'+f"{session}-bpod_zaber.npy")
        #reply = os.system(copy_command)
        if not only_csv_metadata:
            subprocess.run(copy_command,shell=True)
        bpod_file_names = np.unique(bpod_dict['bpod_file_names'])
        
        command_list = []
        for f in bpod_file_names:
            copy_command = 'gsutil -m cp -r {} {} '.format('/home/jupyter/bucket/Data/Behavior/raw/KayvonScope/BCI/experiments/BCI/setups/KayvonScope/sessions/'+f[:-4],
                                                     str(modality1_source)+'/')
            command_list.append(copy_command)

        bash_command = r" && ".join(command_list)
        #os.system(bash_command)
        if not only_csv_metadata:
            for bash_command in command_list:
                subprocess.run(bash_command,shell=True)

        
        #copy camera data in a single folder under side & bottom
        modality2 = 'behavior_videos'
        modality2_source = Path(os.path.join(CO_save_path,'{}-{}'.format(mouse_id,session),'behavior_videos'))
        modality2_source.mkdir(parents=True, exist_ok=True)
        modality2_source_side = Path(os.path.join(CO_save_path,'{}-{}'.format(mouse_id,session),'behavior_videos','side'))
        modality2_source_side.mkdir(parents=True, exist_ok=True)
        modality2_source_bottom = Path(os.path.join(CO_save_path,'{}-{}'.format(mouse_id,session),'behavior_videos','bottom'))
        modality2_source_bottom.mkdir(parents=True, exist_ok=True)
        
        side_folders = []
        bottom_folders = []
        
        for m in bpod_dict['behavior_movie_name_list']:
            if type(m) == np.ndarray:
                for movie_name in m:
                    if 'side' in movie_name:
                        side_folders.append(os.path.join('/home/jupyter/bucket/Data/Behavior_videos/raw/Bergamo-2P-Photostim',*movie_name.split('/')[5:-1]))
                    elif 'bottom' in movie_name:
                        bottom_folders.append(os.path.join('/home/jupyter/bucket/Data/Behavior_videos/raw/Bergamo-2P-Photostim',*movie_name.split('/')[5:-1]))
                    else:
                        wtf
        side_folders = np.unique(side_folders)
        command_list = []
        for s in side_folders:
            dest  = Path(os.path.join(modality2_source_side,s.split('/')[-1]))
            dest.mkdir(parents=True, exist_ok=True)
            copy_command = 'gsutil -m rsync {} {} '.format(s,
                                                     str(dest)+'/')
            command_list.append(copy_command)
        bottom_folders = np.unique(bottom_folders)
        for b in bottom_folders:
            dest  = Path(os.path.join(modality2_source_bottom,b.split('/')[-1]))
            dest.mkdir(parents=True, exist_ok=True)
            copy_command = 'gsutil -m rsync {} {} '.format(b,
                                                     str(dest)+'/')
            command_list.append(copy_command)

        bash_command = r" && ".join(command_list)
        #os.system(bash_command)
        if not only_csv_metadata:
            for bash_command in command_list:
                subprocess.run(bash_command,shell=True)
        #asd
        
        
        upload_dict['platform'].append(platform)
        upload_dict['acq_datetime'].append(acq_datetime)
        upload_dict['subject_id'].append(subject_id)
        upload_dict['s3_bucket'].append(s3_bucket)
        upload_dict['modality0'].append(modality0)
        upload_dict['modality0.source'].append(modality0_source)
        upload_dict['modality1'].append(modality1)
        upload_dict['modality1.source'].append(modality1_source)
        upload_dict['modality2'].append(modality2)
        upload_dict['modality2.source'].append(modality2_source)
        if len(upload_dict['platform'])>1:
            break
    if len(upload_dict['platform'])>1:
        break
output_df = pd.DataFrame.from_dict(upload_dict)
output_df.to_csv(os.path.join(CO_save_path,'uplpoad_job_ALL.csv'))
# Out:
# file_00001.tif is not a proper session folder, skipping
# file_00002.tif is not a proper session folder, skipping
# file_00003.tif is not a proper session folder, skipping
# file_00004.tif is not a proper session folder, skipping
# file_00005.tif is not a proper session folder, skipping
# stack_new_2_00001.stim is not a proper session folder, skipping
# stack_new_2_00001.tif is not a proper session folder, skipping
# stack_new_3_00001.stim is not a proper session folder, skipping
# stack_new_3_00001.tif is not a proper session folder, skipping
# 240221 is not a proper session folder, skipping
# data_BCINM_012_041124.npy is not a proper session folder, skipping
# 040822_2 is not a proper session folder, skipping
# 041222_2 is not a proper session folder, skipping
# 041322_2 is not a proper session folder, skipping
# 043022_2 is not a proper session folder, skipping
# file_00001.tif is not a proper session folder, skipping
# 051322_2 is not a proper session folder, skipping
# 060322_1 is not a proper session folder, skipping
# _slm21_00001.stim is not a proper session folder, skipping
# 071422_2 is not a proper session folder, skipping
# Neuron6_00001.stim is not a proper session folder, skipping
# Neuron6_00001.tif is not a proper session folder, skipping
# Neuron6_00002.tif is not a proper session folder, skipping
# Neuron6_00003.tif is not a proper session folder, skipping
# Neuron6_00004.tif is not a proper session folder, skipping
# Neuron6_00005.tif is not a proper session folder, skipping
# Neuron6_00006.tif is not a proper session folder, skipping
# Neuron6_00007.tif is not a proper session folder, skipping
# Neuron6_00008.tif is not a proper session folder, skipping
# Neuron6_00009.tif is not a proper session folder, skipping
# Neuron6_00010.tif is not a proper session folder, skipping
# tilted_071422 is not a proper session folder, skipping
# 071222_2 is not a proper session folder, skipping
# FAIL_071222 is not a proper session folder, skipping
# stack_00001.stim is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# stack_Motion_00001.csv is not a proper session folder, skipping
# file2722_00001.stim is not a proper session folder, skipping
# file2722_00001.tif is not a proper session folder, skipping
# file2722_00002.tif is not a proper session folder, skipping
# file2722_00003.tif is not a proper session folder, skipping
# file2722_00004.tif is not a proper session folder, skipping
# file2722_00005.tif is not a proper session folder, skipping
# file2722_00006.tif is not a proper session folder, skipping
# file2722_00007.tif is not a proper session folder, skipping
# file2722_00008.tif is not a proper session folder, skipping
# file2722_00009.tif is not a proper session folder, skipping
# file2722_00010.tif is not a proper session folder, skipping
# file2722_00011.tif is not a proper session folder, skipping
# file2722_00012.tif is not a proper session folder, skipping
# file2722_00013.tif is not a proper session folder, skipping
# file2722_00014.tif is not a proper session folder, skipping
# file2722_00015.tif is not a proper session folder, skipping
# file2722_00016.tif is not a proper session folder, skipping
# file2722_00017.tif is not a proper session folder, skipping
# file2722_00018.tif is not a proper session folder, skipping
# file2722_00019.tif is not a proper session folder, skipping
# file2722_00020.tif is not a proper session folder, skipping
# file2722_00021.tif is not a proper session folder, skipping
# file2722_00022.tif is not a proper session folder, skipping
# file2722_00023.tif is not a proper session folder, skipping
# file2722_00024.tif is not a proper session folder, skipping
# file2722_00025.tif is not a proper session folder, skipping
# file2722_00026.tif is not a proper session folder, skipping
# file2722_00027.tif is not a proper session folder, skipping
# file2722_00028.tif is not a proper session folder, skipping
# file2722_00029.tif is not a proper session folder, skipping
# file2722_00030.tif is not a proper session folder, skipping
# file2722_00031.tif is not a proper session folder, skipping
# file2722_00032.tif is not a proper session folder, skipping
# file2722_00033.tif is not a proper session folder, skipping
# file2722_00034.tif is not a proper session folder, skipping
# file2722_00035.tif is not a proper session folder, skipping
# file2722_00036.tif is not a proper session folder, skipping
# file2722_00037.tif is not a proper session folder, skipping
# file2722_00038.tif is not a proper session folder, skipping
# file2722_00039.tif is not a proper session folder, skipping
# file2722_00040.tif is not a proper session folder, skipping
# file2722_00041.tif is not a proper session folder, skipping
# file2722_00042.tif is not a proper session folder, skipping
# file2722_00043.tif is not a proper session folder, skipping
# file2722_00044.tif is not a proper session folder, skipping
# file2722_00045.tif is not a proper session folder, skipping
# file2722_00046.tif is not a proper session folder, skipping
# file2722_BCIparams_46.mat is not a proper session folder, skipping
# file2722_IntegrationRois_00001.csv is not a proper session folder, skipping
# file272_00001.stim is not a proper session folder, skipping
# file272_00002.stim is not a proper session folder, skipping
# file272_BCIparams_1.mat is not a proper session folder, skipping
# file272_BCIparams_2.mat is not a proper session folder, skipping
# file272_IntegrationRois_00001.csv is not a proper session folder, skipping
# file272_IntegrationRois_00002.csv is not a proper session folder, skipping
# file27_00001.stim is not a proper session folder, skipping
# file27_00001.tif is not a proper session folder, skipping
# file27_00002.tif is not a proper session folder, skipping
# file27_00003.tif is not a proper session folder, skipping
# file27_00004.tif is not a proper session folder, skipping
# file27_00005.tif is not a proper session folder, skipping
# file27_00006.tif is not a proper session folder, skipping
# file27_BCIparams_6.mat is not a proper session folder, skipping
# file27_IntegrationRois_00001.csv is not a proper session folder, skipping
# file3344_00001.stim is not a proper session folder, skipping
# file3344_00001.tif is not a proper session folder, skipping
# file3344_00002.tif is not a proper session folder, skipping
# file3344_00003.tif is not a proper session folder, skipping
# file3344_00004.tif is not a proper session folder, skipping
# file3344_00005.tif is not a proper session folder, skipping
# file3344_00006.tif is not a proper session folder, skipping
# file3344_00007.tif is not a proper session folder, skipping
# file3344_00008.tif is not a proper session folder, skipping
# file3344_00009.tif is not a proper session folder, skipping
# file3344_00010.tif is not a proper session folder, skipping
# file3344_00011.tif is not a proper session folder, skipping
# file3344_00012.tif is not a proper session folder, skipping
# file3344_00013.tif is not a proper session folder, skipping
# file3344_00014.tif is not a proper session folder, skipping
# file3344_00015.tif is not a proper session folder, skipping
# file3344_00016.tif is not a proper session folder, skipping
# file3344_00017.tif is not a proper session folder, skipping
# file3344_00018.tif is not a proper session folder, skipping
# file3344_00019.tif is not a proper session folder, skipping
# file3344_00020.tif is not a proper session folder, skipping
# file3344_00021.tif is not a proper session folder, skipping
# file3344_00022.tif is not a proper session folder, skipping
# file3344_00023.tif is not a proper session folder, skipping
# file3344_00024.tif is not a proper session folder, skipping
# file3344_BCIparams_24.mat is not a proper session folder, skipping
# file3344_BCIparams_25.mat is not a proper session folder, skipping
# file3344_IntegrationRois_00001.csv is not a proper session folder, skipping
# file_BCIparams_1.mat is not a proper session folder, skipping
# stack_00001.stim is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# stack_BCIparams_1.mat is not a proper session folder, skipping
# stack_BCIparams_2.mat is not a proper session folder, skipping
# 091323-stacks is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# photostim.roi is not a proper session folder, skipping
# roigroup.roi is not a proper session folder, skipping
# session_070623_analyzed_dat_small_spont070623114.mat is not a proper session folder, skipping
# session_072023_analyzed_dat_small_spont0720238704.mat is not a proper session folder, skipping
# session_072223_analyzed_dat_small_spont0722238491.mat is not a proper session folder, skipping
# session_072323_analyzed_dat_small_spont0723231904.mat is not a proper session folder, skipping
# session_072423_analyzed_dat_small_spont0724232524.mat is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# stack_00001_old.tif is not a proper session folder, skipping
# test is not a proper session folder, skipping
# session_071223_analyzed_dat_small_spont0712239242.mat is not a proper session folder, skipping
# session_071923_analyzed_dat_small_spont0719239005.mat is not a proper session folder, skipping
# session_072223_analyzed_dat_small_spont0722239440.mat is not a proper session folder, skipping
# session_072323_analyzed_dat_small_spont0723233627.mat is not a proper session folder, skipping
# session_072423_analyzed_dat_small_spont0724236965.mat is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# session_070623_analyzed_dat_small_spont0706234596.mat is not a proper session folder, skipping
# session_071923_analyzed_dat_small_spont0719236825.mat is not a proper session folder, skipping
# session_072123_analyzed_dat_small_neuron45072123306.mat is not a proper session folder, skipping
# session_072323_analyzed_dat_small_spont0723238431.mat is not a proper session folder, skipping
# session_072423_analyzed_dat_small_spont0724233630.mat is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# _slm1_00001.stim is not a proper session folder, skipping
# _slm1_00001.tif is not a proper session folder, skipping
# _slm1_0001.h5 is not a proper session folder, skipping
# _slm1_BCIparams_1.mat is not a proper session folder, skipping
# _slm1_BCIparams_2.mat is not a proper session folder, skipping
# _slm1_Motion_00001.csv is not a proper session folder, skipping
# file_00001.stim is not a proper session folder, skipping
# file_00001.tif is not a proper session folder, skipping
# file_00002.tif is not a proper session folder, skipping
# file_BCIparams_2.mat is not a proper session folder, skipping
# file_BCIparams_3.mat is not a proper session folder, skipping
# file_IntegrationRois_00001.csv is not a proper session folder, skipping
# neuron7_BCIparams_1.mat is not a proper session folder, skipping
# session_072223_analyzed_dat_small_spont0722235616.mat is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# session_072223_analyzed_dat_small_spont0722236605.mat is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# stack_00002.tif is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# stack_00002.tif is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# stack_
# neuron10_threshold_2.mat is not a proper session folder, skipping
# spont_00001.stim is not a proper session folder, skipping
# spont_00001.tif is not a proper session folder, skipping
# spont_00002.tif is not a proper session folder, skipping
# spont_00003.tif is not a proper session folder, skipping
# spont_00004.tif is not a proper session folder, skipping
# spont_00005.tif is not a proper session folder, skipping
# spont_00006.tif is not a proper session folder, skipping
# spont_00007.tif is not a proper session folder, skipping
# spont_00008.tif is not a proper session folder, skipping
# spont_00009.tif is not a proper session folder, skipping
# spont_00010.tif is not a proper session folder, skipping
# spont_00011.tif is not a proper session folder, skipping
# spont_00012.tif is not a proper session folder, skipping
# spont_00013.tif is not a proper session folder, skipping
# spont_00014.tif is not a proper session folder, skipping
# spont_00015.tif is not a proper session folder, skipping
# spont_00016.tif is not a proper session folder, skipping
# spont_IntegrationRois_00001.csv is not a proper session folder, skipping
# spont_Motion_00001.csv is not a proper session folder, skipping
# stack_00001.stim is not a proper session folder, skipping
# stack_00001.tif is not a proper session folder, skipping
# missing subject id for BCINM_004 ..  skipping
# missing subject id for BCINM_006 ..  skipping
# missing subject id for BCINM_007_2 ..  skipping
# missing subject id for BCINM_008_2 ..  skipping
# missing subject id for BCINM_010 ..  skipping
# missing subject id for BCINM_012 ..  skipping
# missing subject id for BCINM_013 ..  skipping
# missing subject id for BCINM_014 ..  skipping
# missing subject id for BCINM_015 ..  skipping
# no behavior found, skipping
# no behavior found, skipping
# Copying file:///home/jupyter/bucket/Data/Behavior/BCI_exported/Bergamo-2P-Photostim/BCI_26/033022-bpod_zaber.npy...
# / [1 files][  3.5 MiB/  3.5 MiB]
# Operation completed over 1 objects/3.5 MiB.
# Copying file:///home/jupyter/bucket/Data/Behavior/raw/KayvonScope/BCI/experiments/BCI/setups/KayvonScope/sessions/20220330-124230/20220330-124230.csv...
# Copying file:///home/jupyter/bucket/Data/Behavior/raw/KayvonScope/BCI/experiments/BCI/setups/KayvonScope/sessions/20220330-124230/__init__.py...
# Copying file:///home/jupyter/bucket/Data/Behavior/raw/KayvonScope/BCI/experiments/BCI/setups/KayvonScope/sessions/20220330-124230/user_settings.py...
# Copying file:///home/jupyter/bucket/Data/Behavior/raw/KayvonScope/BCI/experiments/BCI/setups/KayvonScope/sessions/20220330-124230/__pycache__/user_settings.cpython-36.pyc...
# - [4/4 files][  7.0 MiB/  7.0 MiB] 100% Done
# Operation completed over 4 objects/7.0 MiB.
# Copying file:///home/jupyter/bucket/Data/Behavior/BCI_exported/Bergamo-2P-Photostim/BCI_26/033122-bpod_zaber.npy...
# / [1 files][  6.7 MiB/  6.7 MiB]
# Operation completed over 1 objects/6.7 MiB.
# Copying file:///home/jupyter/bucket/Data/Behavior/raw/KayvonScope/BCI/experiments/BCI/setups/KayvonScope/sessions/20220331-144709/20220331-144709.csv...
# Copying file:///home/jupyter/bucket/Data/Behavior/raw/KayvonScope/BCI/experiments/BCI/setups/KayvonScope/sessions/20220331-144709/__init__.py...
# Copying file:///home/jupyter/bucket/Data/Behavior/raw/KayvonScope/BCI/experiments/BCI/setups/KayvonScope/sessions/20220331-144709/user_settings.py...
# Copying file:///home/jupyter/bucket/Data/Behavior/raw/KayvonScope/BCI/experiments/BCI/setups/KayvonScope/sessions/20220331-144709/__pycache__/user_settings.cpython-36.pyc...
# - [4/4 files][  3.4 MiB/  3.4 MiB] 100% Done
# Operation completed over 4 objects/3.4 MiB.

# %%
original_sessions
# Out:
#     Unnamed: 0            platform         acq_datetime  subject_id  \
# 0            0  single-plane-ophys  2022-04-19 12-05-37      608551
# 1            1  single-plane-ophys  2022-04-20 15-53-43      608551
# 2            2  single-plane-ophys  2022-04-21 10-48-04      608551
# 3            3  single-plane-ophys  2022-04-22 12-39-41      608551
# 4            4  single-plane-ophys  2022-04-25 12-39-50      608551
# ..         ...                 ...                  ...         ...
# 81          81  single-plane-ophys  2022-07-05 14-59-11      621023
# 82          82  single-plane-ophys  2022-07-06 10-10-51      621023
# 83          83  single-plane-ophys  2022-07-07 09-43-59      621023
# 84          84  single-plane-ophys  2022-07-12 13-13-43      621023
# 85          85  single-plane-ophys  2022-07-14 11-55-57      621023
#
#           s3_bucket modality0  \
# 0   aind-ophys-data     ophys
# 1   aind-ophys-data     ophys
# 2   aind-ophys-data     ophys
# 3   aind-ophys-data     ophys
# 4   aind-ophys-data     ophys
# ..              ...       ...
# 81  aind-ophys-data     ophys
# 82  aind-ophys-data     ophys
# 83  aind-ophys-data     ophys
# 84  aind-ophys-data     ophys
# 85  aind-ophys-data     ophys
#
#                                      modality0.source         modality1  \
# 0   /home/jupyter/bucket/Data/Calcium_imaging/raw/...  trained_behavior
# 1   /home/jupyter/bucket/Data/Calcium_imaging/raw/...  trained_behavior
# 2   /home/jupyter/bucket/Data/Calcium_imaging/raw/...  trained_behavior
# 3   /home/jupyter/bucket/Data/Calcium_imaging/raw/...  trained_behavior
# 4   /home/jupyter/bucket/Data/Calcium_imaging/raw/...  trained_behavior
# ..                                                ...               ...
# 81  /home/jupyter/bucket/Data/Calcium_imaging/raw/...  trained_behavior
# 82  /home/jupyter/bucket/Data/Calcium_imaging/raw/...  trained_behavior
# 83  /home/jupyter/bucket/Data/Calcium_imaging/raw/...  trained_behavior
# 84  /home/jupyter/bucket/Data/Calcium_imaging/raw/...  trained_behavior
# 85  /home/jupyter/bucket/Data/Calcium_imaging/raw/...  trained_behavior
#
#                                      modality1.source        modality2  \
# 0   /home/jupyter/bucket/CodeOcean_transfer/BCI_29...  behavior_videos
# 1   /home/jupyter/bucket/CodeOcean_transfer/BCI_29...  behavior_videos
# 2   /home/jupyter/bucket/CodeOcean_transfer/BCI_29...  behavior_videos
# 3   /home/jupyter/bucket/CodeOcean_transfer/BCI_29...  behavior_videos
# 4   /home/jupyter/bucket/CodeOcean_transfer/BCI_29...  behavior_videos
# ..                                                ...              ...
# 81  /home/jupyter/bucket/CodeOcean_transfer/BCI_39...  behavior_videos
# 82  /home/jupyter/bucket/CodeOcean_transfer/BCI_39...  behavior_videos
# 83  /home/jupyter/bucket/CodeOcean_transfer/BCI_39...  behavior_videos
# 84  /home/jupyter/bucket/CodeOcean_transfer/BCI_39...  behavior_videos
# 85  /home/jupyter/bucket/CodeOcean_transfer/BCI_39...  behavior_videos
#
#                                      modality2.source
# 0   /home/jupyter/bucket/CodeOcean_transfer/BCI_29...
# 1   /home/jupyter/bucket/CodeOcean_transfer/BCI_29...
# 2   /home/jupyter/bucket/CodeOcean_transfer/BCI_29...
# 3   /home/jupyter/bucket/CodeOcean_transfer/BCI_29...
# 4   /home/jupyter/bucket/CodeOcean_transfer/BCI_29...
# ..                                                ...
# 81  /home/jupyter/bucket/CodeOcean_transfer/BCI_39...
# 82  /home/jupyter/bucket/CodeOcean_transfer/BCI_39...
# 83  /home/jupyter/bucket/CodeOcean_transfer/BCI_39...
# 84  /home/jupyter/bucket/CodeOcean_transfer/BCI_39...
# 85  /home/jupyter/bucket/CodeOcean_transfer/BCI_39...
#
# [86 rows x 11 columns]

# %%
original_sessions = pd.read_csv(os.path.join(CO_save_path,'uplpoad_job.csv'))

# %%
CO_save_path = "/home/jupyter/bucket/CodeOcean_transfer/"
folders_to_upload = os.listdir(CO_save_path)

# %%
import json
json_list = []
for f_ in folders_to_upload:
    if '.' in f_:
        continue
    files = os.listdir(os.path.join(CO_save_path,f_))
    with open(os.path.join(CO_save_path,f_,'uppload_job_part.json')) as json_data:
        d = json.load(json_data)
    json_list.append(d)
all_sessions = pd.DataFrame.from_dict(json_list)

# %%
json_list_needed = []
for j in json_list:
    if sum((original_sessions['acq_datetime'] == j['acq_datetime']) & (original_sessions['subject_id'] == j['subject_id'])) == 0:
        json_list_needed.append(j)
    # else:
    #     print('skipped')
needed_sessions = pd.DataFrame.from_dict(json_list_needed)  
needed_sessions.to_csv(os.path.join(CO_save_path,'uplpoad_job_NEW.csv'))
